# %%
print("hello")
# Out:
# hello

# %%
import json

with open("old_chat",'r') as file:
    datas=json.load(file)

# %%
datas[1].get("content")
# Out:
# 'Hello'

# %%
lists=[]

for data in datas:
    # print("content \n",data.get("content",{}))
    # print("role",data.get("role"))
    if data.get('data')==None:
        pass
    else:
        # print(data.get("data",{}))
        if(data.get("role")=="assistant"):
            entry=data.get("data",[])
            for x in entry:
                if x.get("topic")=="input":
                    print(x['payload'])
# Out:
# {'type': 'services', 'action': 'multi-selection', 'data': {'default': '', 'options': [{'name': 'roofing', 'details': '', 'id': 'roofing', 'actions': ['install', 'repair']}, {'name': 'siding', 'details': '', 'id': 'siding', 'actions': ['install', 'repair']}, {'name': 'windows', 'details': '', 'id': 'windows', 'actions': ['install', 'replace']}, {'name': 'doors', 'details': '', 'id': 'doors', 'actions': ['install', 'replace']}, {'name': 'gutters', 'details': '', 'id': 'gutters', 'actions': ['install', 'repair']}, {'name': 'fencing', 'details': '', 'id': 'fencing', 'actions': ['install', 'repair']}, {'name': 'decking', 'details': '', 'id': 'decking', 'actions': ['install', 'repair']}, {'name': 'solar roofing', 'details': '', 'id': 'solar roofing', 'actions': ['install', 'repair']}, {'name': 'carpentry', 'details': '', 'id': 'carpentry', 'actions': ['install', 'repair']}, {'name': 'window replacement', 'details': '', 'id': 'window replacement', 'actions': ['install', 'replace']}]}}
# {'type': 'services', 'action': 'multi-selection', 'data': {'default': '', 'options': [{'name': 'roofing', 'details': '', 'id': 'roofing', 'actions': ['install', 'repair']}, {'name': 'siding', 'details': '', 'id': 'siding', 'actions': ['install', 'repair']}, {'name': 'windows', 'details': '', 'id': 'windows', 'actions': ['install', 'replace']}, {'name': 'doors', 'details': '', 'id': 'doors', 'actions': ['install', 'replace']}, {'name': 'gutters', 'details': '', 'id': 'gutters', 'actions': ['install', 'repair']}, {'name': 'fencing', 'details': '', 'id': 'fencing', 'actions': ['install', 'repair']}, {'name': 'decking', 'details': '', 'id': 'decking', 'actions': ['install', 'repair']}, {'name': 'solar roofing', 'details': '', 'id': 'solar roofing', 'actions': ['install', 'repair']}, {'name': 'carpentry', 'details': '', 'id': 'carpentry', 'actions': ['install', 'repair']}, {'name': 'window replacement', 'details': '', 'id': 'window replacement', 'actions': ['install', 'replace']}]}}
# {'type': 'images', 'data': {'default': '', 'action': 'get'}}
# {'type': 'images', 'data': {'default': '', 'action': 'get'}}

# %%
# Out:
# ' I appreciate your patience, Vikash! To provide an accurate estimate for your roof repair, could you clarify your preference between repair and replacement? service options for you!'

# %%
json_string ='{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'

# %%
json_Dat=json.loads(json_string)

# %%
type(json_Dat)
# Out:
# dict

# %%
json_Dat['car']['year']
# Out:
# 2022
