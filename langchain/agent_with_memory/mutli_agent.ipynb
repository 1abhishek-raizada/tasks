# %%
# %pip install langchain_experimental

# %%
from typing import Annotated,Literal
from langchain_tavily import TavilySearch
from langchain_core.tools import tool
from langchain_experimental.utilities import PythonREPL
from typing_extensions import TypedDict
from langgraph.graph import MessagesState,END,StateGraph,START
from langgraph.types import Command
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import create_react_agent

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
groq_model=ChatGroq(model="Gemma2-9b-It")

# %%
groq_model.invoke("hello").content
# Out:
# 'Hello! 👋  How can I help you today? 😊\n'

# %%
tavily_search=TavilySearch()

# %%
tavily_search.invoke("iran vs israel")
# Out:
# {'query': 'iran vs israel',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'title': 'Iran-Israel proxy conflict - Wikipedia',
#    'url': 'https://en.wikipedia.org/wiki/Iran–Israel_proxy_conflict',
#    'content': 'Iran-Israel proxy conflict Part of the post-Cold War era, the Arab-Israeli conflict, the Iran-Saudi Arabia proxy conflict, and the Iran-Turkey proxy conflict Israel (orange) and Iran (green) shown within the Middle East Date 16 February 1985 - ongoing (40 years, 3 months, 4 weeks and 1 day) Location Worldwide Status Ongoing: Iran reinforces Syria and Hezbollah Israel tries to',
#    'score': 0.7797419,
#    'raw_content': None},
#   {'title': 'How the militaries of Israel and Iran compare | AP News',
#    'url': 'https://apnews.com/article/iran-israel-militaries-mideast-us-613e71aff67f6e1701981583bf699bc6',
#    'content': "Israel already curtailed Iran's ability to fight back, having decimated Iranian proxies Hamas and Lebanon's Hezbollah and heavily bombed Iran's air defense systems. Ahead of Friday's strikes, Iran had vowed massive retaliation for any attack, not just against Israel but also U.S. bases in the region, with one official vowing to",
#    'score': 0.69274646,
#    'raw_content': None},
#   {'title': 'Israel and Iran launch daytime attacks as conflict deepens',
#    'url': 'https://www.cnn.com/world/live-news/israel-iran-strikes-news-06-15-25',
#    'content': 'Live updates: Israel and Iran resume missile strikes as conflict deepens | CNN More than an hour after Israel’s Home Front Command told residents across Israel to remain close to bomb shelters in anticipation of another Iranian barrage, air raid sirens had yet to be triggered as the Israeli military said it was striking missile launch sites in Iran. Israel is conducting strikes on surface-to-surface missile sites in central Iran, the Israel Defense Forces (IDF) said on Sunday night. Israel conducted a “wide-scale” wave of strikes on Sunday targeting several weapons production sites in Iran, the Israeli military said. After Israel began striking Iran on Friday, Trump told CNN: “I don’t know if you know but I gave them a 60-day warning and today is day 61.”',
#    'score': 0.6899958,
#    'raw_content': None},
#   {'title': 'Live updates: Israel-Iran attacks, missile strikes on Tel Aviv, Tehran ...',
#    'url': 'https://edition.cnn.com/world/live-news/israel-iran-strikes-news-06-14-25',
#    'content': 'Israeli Defense Minister Israel Katz said Saturday that people in Tehran will “pay a heavy price” if Iran continues with its missile attacks, warning that the Iranian capital “will burn.” It is unclear how many civilians have died in Israeli strikes, but Iran’s UN envoy said that at least 78 people were killed in Israel’s attacks on Friday. The Israeli military is set to resume striking targets in Iran’s capital Tehran, the head of the Israel Defense Forces (IDF) said Saturday. Israeli security officials said that ahead of the attack Israel had established a base for launching explosive drones inside Iran, and the drones were later used to target missile launchers near Tehran.',
#    'score': 0.6778372,
#    'raw_content': None},
#   {'title': 'Live Updates: Israel Says It Attacked Headquarters of Powerful Iranian ...',
#    'url': 'https://www.nytimes.com/live/2025/06/15/world/iran-israel-nuclear/iran-israel-shelters',
#    'content': 'The Israeli military said in a statement early on Monday morning that it was striking missile sites in central Iran, and warned Israelis to stay close to shelters, signaling that a potential Iranian attack was forthcoming. The Israeli military appears to have destroyed an Iranian refueling plane at an Iranian airport 1,400 miles from Israel, close to Iran’s borders with Turkmenistan and Afghanistan, according to satellite imagery and a video analyzed by The New York Times. The location of the attack, at Mashhad Airport in the far east of the country, shows “at the very least that Israel can hit just about any target it wants in Iran,” said Afshon Ostovar, an Iran military expert at the Naval Postgraduate School in Monterey, Calif. A building damaged by an Iranian missile attack in Bat Yam, Israel, on Sunday.Credit...Avishag Shaar-Yashuv for The New York Times',
#    'score': 0.5417246,
#    'raw_content': None}],
#  'response_time': 1.96}

# %%
repl=PythonREPL()

# %%
"""
6x5x4x3x2x1
5x4x3x2x1
4x3x2x1

"""
