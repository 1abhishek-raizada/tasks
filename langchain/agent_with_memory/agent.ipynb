# %%
# %pip install langchain
# %pip install langchain_community
# %pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 580.6/580.6 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: packaging0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/29 [pydantic-core]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━  6/29 [pydantic-core]
#     Uninstalling packaging-25.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/29 [pydantic-core]
#       Successfully uninstalled packaging-25.0━━━━━━━━━━━━━━━━━  6/29 [pydantic-core]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [langchain]29 [langchain]core]lt]]
# ...

# %%
from langchain.agents import initialize_agent, load_tools, AgentType
from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import FileChatMessageHistory
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import os
from getpass import getpass

os.environ["GOOGLE_API_KEY"] = getpass("Enter your GOOGLE API Key: ")

# %%
import os
from getpass import getpass

os.environ["TAVILY_API_KEY"] = getpass("Enter your TAVILY API Key: ")

# %%
from langchain_community.tools import TavilySearchResults

# %%
llm=ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest",temperature=0)
search_tools=TavilySearchResults()
tools=[search_tools]

# %%
from langchain.prompts import ChatPromptTemplate,MessagesPlaceholder

# %%
def chat_agent(session_id):
    history=FileChatMessageHistory(file_path=f"{session_id}_history.json")
    memory=ConversationBufferMemory(
        memory_key="history",
        chat_memory=history,
        return_messages=True
    )
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You're a witty, helpful assistant. If needed, use tools to find answers."),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{input}")
    ])

    agent=create_tool_calling_agent( tools=tools,
        llm=llm,
        agent=AgentType.CONVERSATIONAL_REACT_DESCRIPTION,
        memory=memory,
        verbose=True,
        handle_parsing_errors=True,prompt=prompt,)
    return agent

# %%
agent=chat_agent('abhishek')

# %%
agent.run("tell me a joke")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 agent.run("tell me a joke")
#
# File ~/daily/tasks/langchain/agent_with_memory/.venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File ~/daily/tasks/langchain/agent_with_memory/.venv/lib/python3.10/site-packages/langchain/chains/base.py:603, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     601     if len(args) != 1:
#     602         raise ValueError("`run` supports only one positional argument.")
# --> 603     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     604         _output_key
#     605     ]
# ...
